# %% [markdown]
# <a href="https://colab.research.google.com/github/juanfelipegonzalezalfonso/programacion1/blob/main/Tarea_Programaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
personajes = ["Avdol", "Joseph", "Josuke"]
personajes.remove("Avdol")
personajes.append("bulbasaur")
resultado = personajes[1:2]
print(resultado)
# Out:
# ['Josuke']

# %%
respuesta = ("Ora","Ora","Ora")
resultado = (respuesta.count("Ora"), respuesta.index("Ora"))
print(resultado)

# %%
temporada_1 = set(["Jonathan", "Zeppeli", "hamon"])
temporada_4 = set(["Joseph", "Jotaro", "Josuke", "Koichi", "hamon"])
resultado = temporada_1 & temporada_4
print(resultado)
# Out:
# {'hamon'}

# %%
jojobros = {1: "zeppeli", 2: "cesar", 3: "kakyoin"}
jojos = {"zeppeli": "Phantom Blood",
         "cesar": "Battle Tendency",
         "kakyoin": "Stardust Crusaders"}
resultado = jojos[jojobros[2]]
print(resultado)
# Out:
# Battle Tendency
