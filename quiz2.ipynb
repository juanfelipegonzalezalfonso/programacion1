# %% [markdown]
# <a href="https://colab.research.google.com/github/juanfelipegonzalezalfonso/programacion1/blob/main/quiz2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile pedirnotas.py
def pedir_nombre():
  return input("ingrese el nombre del estudiante: ")

def pedir_notas():
  n1 = float(input("nota 1: "))
  n2 = float(input("nota 2: "))
  n3 = float(input("nota 3: "))
  n4 = float(input("nota 4: "))
  return n1, n2, n3, n4
# Out:
# Overwriting pedirnotas.py

# %%
# %%writefile promedio.py
import statistics

def calcular_promedio(n1, n2, n3, n4):
    return (n1 + n2 + n3 + n4) / 4

def mediana(n1, n2, n3, n4):
    return statistics.median([n1, n2, n3, n4])

def moda(n1, n2, n3, n4):
    return statistics.mode([n1, n2, n3, n4])
# Out:
# Overwriting promedio.py

# %%
import importlib
import pedirnotas
importlib.reload(pedirnotas)
notas = pedirnotas.pedir_notas()
# Out:
# nota 1: 2
# nota 2: 3
# nota 3: 4
# nota 4: 5

# %%
import importlib
import pedirnotas
importlib.reload(pedirnotas)
nombre = pedirnotas.pedir_nombre()
# Out:
# ingrese el nombre del estudiante: ok

# %%
import promedio
importlib.reload(promedio)
promedio.calcular_promedio(notas[0], notas[1], notas[2], notas[3])
# Out:
# 2.5

# %%
import promedio
importlib.reload(promedio)
promedio.mediana(notas[0], notas[1], notas[2], notas[3])
# Out:
# 2.0

# %%
import promedio
importlib.reload(promedio)
promedio.moda(notas[0], notas[1], notas[2], notas[3])
# Out:
# 2.0

# %%
prom = promedio.calcular_promedio(notas[0], notas[1], notas[2], notas[3])

print("tu nombre es", nombre)
print("tus notas son", notas)

if prom >= 3:
  print("aprobo", prom)
else:
  print("tonto reprobo", prom)

print("su mediana es",promedio.mediana(notas[0], notas[1], notas[2], notas[3]))
print("su moda es",promedio.moda(notas[0], notas[1], notas[2], notas[3]))
# Out:
# tu nombre es ok
# tus notas son (2.0, 3.0, 4.0, 5.0)
# aprobo 3.5
# su mediana es 3.5
# su moda es 2.0

# %% [markdown]
# En este programa usamos modulos para guardar las funciones que piden notas y nombre, aparte calculan promedio, moda y mediana.
# con las notas que agregamos, y la condicional de que el promedio debe ser mayor a 3, el estudiante aprobó ya que su promedio fue de 3,5, su mediana fue de 3,5 y su moda fue 2
