# %% [markdown]
# <a href="https://colab.research.google.com/github/juanfelipegonzalezalfonso/programacion1/blob/main/Parcial_2260663.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# CREAR MODULOS Y PAQUETES:

import os
os.makedirs("op", exist_ok=True)

# %%writefile op/operaciones.py

# %% [markdown]
# #Juan Felipe Gonzalez Alfonso
# codigo: 2260663

# %% [markdown]
# #Instruccion 1

# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(0)
datos = np.random.randint(130, 196, 50)
datos
# Out:
# array([174, 177, 194, 139, 151, 166, 142, 188, 195, 169, 176, 167, 155,
#        139, 150, 177, 194, 179, 159, 149, 149, 144, 169, 162, 195, 139,
#        187, 162, 161, 153, 165, 185, 158, 164, 130, 130, 166, 183, 135,
#        168, 147, 134, 172, 188, 161, 131, 195, 171, 187, 165])

# %%
df = pd.DataFrame({
    "datos": datos
})
df
# Out:
#     datos
# 0     174
# 1     177
# 2     194
# 3     139
# 4     151
# 5     166
# 6     142
# 7     188
# 8     195
# 9     169
# 10    176
# 11    167
# 12    155
# 13    139
# 14    150
# 15    177
# 16    194
# 17    179
# 18    159
# 19    149
# 20    149
# 21    144
# 22    169
# 23    162
# 24    195
# 25    139
# 26    187
# 27    162
# 28    161
# 29    153
# 30    165
# 31    185
# 32    158
# 33    164
# 34    130
# 35    130
# 36    166
# 37    183
# 38    135
# 39    168
# 40    147
# 41    134
# 42    172
# 43    188
# 44    161
# 45    131
# 46    195
# 47    171
# 48    187
# 49    165

# %%
df.loc[df["datos"]>150]
# Out:
#     datos
# 0     174
# 1     177
# 2     194
# 4     151
# 5     166
# 7     188
# 8     195
# 9     169
# 10    176
# 11    167
# 12    155
# 15    177
# 16    194
# 17    179
# 18    159
# 22    169
# 23    162
# 24    195
# 26    187
# 27    162
# 28    161
# 29    153
# 30    165
# 31    185
# 32    158
# 33    164
# 36    166
# 37    183
# 39    168
# 42    172
# 43    188
# 44    161
# 46    195
# 47    171
# 48    187
# 49    165

# %%
df["datos"].apply(lambda x: (x - 163.92)/19.162932)
# Out:
# 0     0.526016
# 1     0.682568
# 2     1.569697
# 3    -1.300427
# 4    -0.674218
# 5     0.108543
# 6    -1.143875
# 7     1.256593
# 8     1.621881
# 9     0.265095
# 10    0.630384
# 11    0.160727
# 12   -0.465482
# 13   -1.300427
# 14   -0.726402
# 15    0.682568
# 16    1.569697
# 17    0.786936
# 18   -0.256746
# 19   -0.778586
# 20   -0.778586
# 21   -1.039507
# 22    0.265095
# 23   -0.100193
# 24    1.621881
# 25   -1.300427
# 26    1.204409
# 27   -0.100193
# 28   -0.152378
# 29   -0.569850
# 30    0.056359
# 31    1.100040
# 32   -0.308930
# 33    0.004175
# 34   -1.770084
# 35   -1.770084
# 36    0.108543
# 37    0.995672
# 38   -1.509164
# 39    0.212911
# 40   -0.882955
# 41   -1.561348
# 42    0.421647
# 43    1.256593
# 44   -0.152378
# 45   -1.717900
# 46    1.621881
# 47    0.369463
# 48    1.204409
# 49    0.056359
# Name: datos, dtype: float64

# %%
df.describe()
# Out:
#             datos
# count   50.000000
# mean   163.920000
# std     19.162932
# min    130.000000
# 25%    149.250000
# 50%    165.000000
# 75%    177.000000
# max    195.000000

# %% [markdown]
# #el promedio es 163.92, la desviacion estandar de los datos es 19.162932
# #el valor minimo es 130 y el maximo es 195

# %% [markdown]
# #Instruccion 2

# %%
df1 = pd.DataFrame({
    "Nombre": ["ricardo", "pablo", "enrique", "juan", "pedro"],
    "Edad": [22, 24, 30, 35, 18],
    "ingreso": [1000000, 200000, 3500000, 280000, 453000],
    "Pais": ["Venezuela", "Colombia", "Colombia", "Venezuela", "Japon"]
})

# %% [markdown]
# 1

# %%
df1.head(1)
# Out:
#     Nombre  Edad  ingreso       Pais
# 0  ricardo    22  1000000  venezuela

# %% [markdown]
# 2

# %%
df1['Nombre']
# Out:
# 0    ricardo
# 1      pablo
# 2    enrique
# 3       juan
# 4      pedro
# Name: Nombre, dtype: object

# %% [markdown]
# 3

# %%
df1.loc[df1["Edad"] > 23]
# Out:
#     Nombre  Edad  ingreso       Pais
# 1    pablo    24   200000   Colombia
# 2  enrique    30  3500000   Colombia
# 3     juan    35   280000  Venezuela

# %% [markdown]
# 4

# %%
cambio = df1['Edad'].apply(lambda x: x+2)
cambio
# Out:
# 0    24
# 1    26
# 2    32
# 3    37
# 4    20
# Name: Edad, dtype: int64

# %% [markdown]
# 5

# %%
grupo = df1.groupby("Pais")["ingreso"].mean()
grupo
# Out:
# Pais
# Colombia     1850000.0
# Japon         453000.0
# Venezuela     640000.0
# Name: ingreso, dtype: float64

# %% [markdown]
# 6

# %% [markdown]
# #Instruccion 3

# %%
salon1 = np.random.normal(loc=7.2, scale=0.4, size=58)

# %%
salon2 = np.random.gamma(shape=306, scale=0.0229, size=58)

# %%
df2 = pd.DataFrame({
    "salon 1": salon1,
    "salon 2": salon2
})
# Out:
#      salon 1   salon 2
# 0   7.067624  6.828539
# 1   7.005914  6.985332
# 2   7.175915  6.525770
# 3   6.576141  7.003562
# 4   7.083438  6.752986
# 5   7.521629  7.119453
# 6   7.494331  6.707947
# 7   7.118944  7.613854
# 8   7.316099  7.100243
# 9   6.858073  7.250659
# 10  7.069547  6.914744
# 11  6.819099  7.026741
# 12  7.674785  6.929965
# 13  6.737130  7.565145
# 14  7.207720  6.630103
# 15  7.780008  6.345171
# 16  7.460849  7.312655
# 17  7.062292  6.153399
# 18  7.716356  6.565079
# 19  6.879150  6.683194
# 20  6.644365  7.751763
# 21  7.303057  7.611037
# 22  7.650989  6.833424
# 23  8.313973  6.644687
# 24  7.163442  7.295930
# 25  7.188371  5.963593
# 26  7.612230  6.487661
# 27  7.609953  6.890691
# 28  7.833280  7.703536
# 29  7.611664  7.454013
# 30  7.933748  6.509906
# 31  7.003597  7.404815
# 32  6.876212  6.671188
# 33  7.101501  6.362163
# 34  7.019299  7.302888
# 35  6.936755  6.952839
# 36  7.356915  6.326234
# 37  6.641415  7.453293
# 38  7.334758  6.854775
# ...

# %%
df2.describe()
# Out:
#          salon 1    salon 2
# count  58.000000  58.000000
# mean    7.270847   6.968097
# std     0.430047   0.413559
# min     6.268519   5.963593
# 25%     7.030047   6.689382
# 50%     7.218542   6.959590
# 75%     7.566401   7.282300
# max     8.325098   7.751763

# %% [markdown]
# la media(promedio) del salon 1 se encuentra en 7.27, la desviacion estandar es de 0.43, el valor minimo es de 6.26, su maximo es de 8.32 , la mediana del primero es de 7.21, cuantil 25% es 7.03 y 75% de 7.56

# %% [markdown]
# la media(promedio) del salon 2 se encuentra en 6.96, la desviacion estandar es de 0.41, el valor minimo es de 5.96, su maximo es de 7.75 , la mediana del segundo es de 6.95, cuantil 25% es 6.68 y 75% de 7.28

# %% [markdown]
# #4

# %%
from scipy import stats
from scipy.stats import shapiro
shapiro(df2["salon 1"])
# Out:
# ShapiroResult(statistic=np.float64(0.9863598456464102), pvalue=np.float64(0.7586232273214917))

# %%
from scipy import stats
from scipy.stats import shapiro
shapiro(df2["salon 2"])
# Out:
# ShapiroResult(statistic=np.float64(0.9870616707368133), pvalue=np.float64(0.7926118090652816))

# %% [markdown]
# en ambos salones el valor de p es mayor que 0.5, se cumple el suspuesto de normalidad

# %%
stats.ttest_rel(df2["salon 1"], df2["salon 2"])
# Out:
# TtestResult(statistic=np.float64(3.6779502130699595), pvalue=np.float64(0.0005223971223511537), df=np.int64(57))

# %% [markdown]
# no se rechaza porque el porcentaje de desconfianza es del 3.67

# %%
stats.kendalltau(df2["salon 1"], df2["salon 2"])
# Out:
# SignificanceResult(statistic=np.float64(-0.055051421657592255), pvalue=np.float64(0.5415791729603694))

# %% [markdown]
# no estan coorelacionados porque el valor de p es mayor a 0.5

# %%
stats.spearmanr(df2["salon 1"], df2["salon 2"])
# Out:
# SignificanceResult(statistic=np.float64(-0.08296164139161463), pvalue=np.float64(0.5358294634938489))

# %% [markdown]
# no estan coorelacionados porque el valor de p es mayor a 0.5

# %%
import os
os.makedirs("comparacion", exist_ok=True)

# %%
# %%writefile comparacion/pruebat.py

stats.ttest_rel(df2["salon 1"], df2["salon 2"])
# Out:
# Writing comparacion/pruebat.py

# %%
# %%writefile comparacion/cor.py
