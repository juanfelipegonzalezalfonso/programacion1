# %% [markdown]
# <a href="https://colab.research.google.com/github/juanfelipegonzalezalfonso/programacion1/blob/main/nosequepitones2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile pedirnotas.py
def pedir_nombre():
  return input("ingrese el nombre del estudiante: ")

def pedir_notas():
  n1 = float(input("nota 1: "))
  n2 = float(input("nota 2: "))
  n3 = float(input("nota 3: "))
  return n1, n2, n3
# Out:
# Overwriting pedirnotas.py

# %%
# %%writefile promedio.py
import statistics

def calcular_promedio(n1, n2, n3):
    return (n1 + n2 + n3) / 3

def mediana(n1, n2, n3):
    return statistics.median([n1, n2, n3])
# Out:
# Overwriting promedio.py

# %%
import importlib
import pedirnotas
importlib.reload(pedirnotas)
notas = pedirnotas.pedir_notas()
# Out:
# nota 1: 5
# nota 2: 6
# nota 3: 7

# %%
import promedio
importlib.reload(promedio)
promedio.calcular_promedio(notas[0], notas[1], notas[2])
# Out:
# 6.0

# %%
# %%writefile calculos.py

def suma(a, b)
    return a + b
def multiplicar(a, b)
    return a * b
# Out:
# Overwriting calculos.py

# %%
# %%writefile mensajes.py

def saludar(nombre):
    return f"hola (nombre)"
# Out:
# Overwriting mensajes.py

# %%
import os
os.makedirs("src", exist_ok=True)

# %%
# %%writefile src/operaciones.py

def dividir (a, b):
    return a / b
# Out:
# Overwriting src/operaciones.py

# %%
from src.operaciones import dividir

print(dividir(10, 2))
# Out:
# 5.0

# %%
import src.operaciones
src.operaciones.dividir(10, 2)
# Out:
# 5.0
