# %% [markdown]
# <a href="https://colab.research.google.com/github/juanfelipegonzalezalfonso/programacion1/blob/branch_operaciones/operaciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile operaciones.py
def sumar_matrices(A, B):
    if len(A) == len(B) and len(A[0]) == len(B[0]):
        return [[A[i][j] + B[i][j] for j in range(len(A[0]))] for i in range(len(A))] [cite: 27]
    return "Error: Dimensiones incompatibles para suma."

def multiplicar_matrices(A, B):
    if len(A[0]) == len(B):
        return [[sum(A[i][k] * B[k][j] for k in range(len(A[0]))) for j in range(len(B[0]))] for i in range(len(A))] [cite: 28]
    return "Error: Columnas de A deben ser iguales a filas de B."

def hadamard_matrices(A, B):
    if len(A) == len(B) and len(A[0]) == len(B[0]):
        return [[A[i][j] * B[i][j] for j in range(len(A[0]))] for i in range(len(A))] [cite: 29]
    return "Error: Dimensiones incompatibles para Hadamard."

def kronecker(A, B):
    fA, cA = len(A), len(A[0])
    fB, cB = len(B), len(B[0])
    return [[A[i // fB][j // cB] * B[i % fB][j % cB] for j in range(cA * cB)] for i in range(fA * fB)] [cite: 30]
