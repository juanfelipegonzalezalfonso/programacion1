# %% [markdown]
# <a href="https://colab.research.google.com/github/juanfelipegonzalezalfonso/programacion1/blob/main/piton3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cuadrados = [1, 4, 9, 16, 25]
cuadrados
# Out:
# [1, 4, 9, 16, 25]

# %%
cuadrados + [36, 49, 64, 81, 100]
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
cubos = [1, 8, 27, 65, 125] # hay algo

# %%
cubos[3] = 64 # reemplazar el valor incorrecto
print(cubos)
# Out:
# [1, 8, 27, 64, 125]

# %%
cubos.append(6**3)
print(cubos)
# Out:
# [1, 8, 27, 64, 125, 216]

# %%
letras = ["a", "b", "c", "d", "e", "f", "g"]
letras
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
letras[2:5] = ["C", "D", "F"]
letras
# Out:
# ['a', 'b', 'C', 'D', 'F', 'f', 'g']

# %%
letras[2:5] = []
letras
# Out:
# ['a', 'b', 'f', 'g']

# %% [markdown]
# # LISTA 2

# %%
a = ['a', 'b', 'c']
n = [1, 2, 3]
x = [a, n, 5]
x
# Out:
# [['a', 'b', 'c'], [1, 2, 3], 5]

# %%
x[0]
# Out:
# ['a', 'b', 'c']

# %%
x[1][2]
# Out:
# 3

# %%
i = 256*256
print('el valor de i es', i)
# Out:
# el valor de i es 65536

# %% [markdown]
# # Tuplas

# %%
colores = ("rojo","verde", "azul")
colores
# Out:
# ('rojo', 'verde', 'azul')

# %% [markdown]
# # crear una cadena hola mundo e imprimirla, crear una lista hola mundo y cree una tupla con los elementos de hola mundo

# %%
cadena = "hola mundo"
lista = ["h", "o", "l", "a", " ", "m", "u", "n", "d", "o"]
tupla = ("h", "o", "l", "a", " ", "m", "u", "n", "d", "o")
print(cadena)
print(lista)
print(tupla)
# Out:
# hola mundo
# ['h', 'o', 'l', 'a', ' ', 'm', 'u', 'n', 'd', 'o']
# ('h', 'o', 'l', 'a', ' ', 'm', 'u', 'n', 'd', 'o')

# %% [markdown]
# # diccionarios

# %%
alumno = {"nombre": "juan", "edad": 18, "curso": "4 año"}
alumno
# Out:
# {'nombre': 'juan', 'edad': 18, 'curso': '4 año', 'sisben': 'A1'}

# %%
alumno ["edad"]
# Out:
# 18

# %%
alumno ["edad"] = 19
alumno
# Out:
# {'nombre': 'juan', 'edad': 19, 'curso': '4 año'}

# %%
alumno ["sisben"] = "A1"
alumno
# Out:
# {'nombre': 'juan', 'edad': 18, 'curso': '4 año', 'sisben': 'A1'}

# %%
del alumno["curso"]
alumno
# Out:
# {'nombre': 'juan', 'edad': 18, 'sisben': 'A1'}

# %%
alumno [""]

# %% [markdown]
# #conjuntos

# %%
colores = {'rojo', 'verde', 'azul'}
colores
# Out:
# {'azul', 'rojo', 'verde'}

# %%
colores1 = {'rojo', 'verde', 'azul', 'verde'}
colores1
# Out:
# {'azul', 'rojo', 'verde'}

# %%
colores1 == colores
# Out:
# True

# %% [markdown]
# #los conjuntos no estan indexados

# %%
for color in colores:
  print(color)
# Out:
# verde
# azul
# rojo

# %%
lista = [1, 2 , 3]

# %%
tupla = tuple(lista)
tupla
# Out:
# (1, 2, 3)

# %%
conjunto = set(lista)
conjunto
# Out:
# {1, 2, 3}

# %%
lista1 = [1, 2, 2, 3]
set(lista1)
# Out:
# {1, 2, 3}

# %%
lista2 = [("nombre", "ana"), ("edad", 20)]
diccionario = dict(lista2)
diccionario
# Out:
# {'nombre': 'ana', 'edad': 20}

# %% [markdown]
# las listas simples no se pueden convertir en diccionarios

# %%
lista = ["ana", 20]
dict(lista) #error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3221919542.py in <cell line: 0>()
#       1 lista = ["ana", 20]
# ----> 2 dict(lista) #error
#
# ValueError: dictionary update sequence element #0 has length 3; 2 is required
